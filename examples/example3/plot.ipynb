# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = np.load("./output/results.npy")
data.shape
# Out:
# (1661, 4, 17)

# %%
plt.figure(figsize=(10,3))
plt.plot(data[:, 0, -1], color="red")
plt.plot(data[:, 1, -1], color="blue")
plt.plot(data[:, 2, -1], color="green")

plt.yscale('log')
plt.xscale('log')

# %%
plt.figure(figsize=(10,3))
plt.plot(data[:48, 3, -1], color="black")
# plt.plot(results[:, 1, -1], color="blue")
# plt.plot(results[:, 2, -1], color="green")

# plt.yscale('log')
# plt.xscale('log')
