# %% [markdown]
# # PHT3D Example 13 — MF6PQC reproduction
#
# The solid curves are the MF6PQC outlet histories, dashed curves are the verified PHT3D results, and points are the Appelo et al. measurements included with the official example. Panel layout, units, colours, and axis limits follow the original figure.

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from plot_utils import plot_breakthrough

CASE_DIR = Path.cwd()
if CASE_DIR.name != 'PHT3D_E13':
    CASE_DIR = CASE_DIR / 'examples' / 'PHT3D_E13'
plt.rcParams.update({'font.size': 9, 'figure.dpi': 120})

# %%
fig, axes = plot_breakthrough(CASE_DIR)
plt.show()
