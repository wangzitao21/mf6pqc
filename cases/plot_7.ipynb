# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = np.load("./output/PHT3D_CASE_7/PHT3D_CASE_7_results.npy")
data.shape
# Out:
# (121, 5, 41)

# %%
out_log = data[-1].reshape(5, 41)

fig = plt.figure(figsize=(7, 8))
ax = fig.add_subplot(5, 1, 1)
ax.plot(out_log[0, :]* 1000)
ax.set_title("S_a")
ax.set_xlim(0, 40)
ax.set_ylim(0.0, 1.0)

ax = fig.add_subplot(5, 1, 2)
ax.plot(out_log[1, :]* 1000)
ax.set_title("S_b")
ax.set_xlim(0, 40)
ax.set_ylim(0.0, 0.2)

ax = fig.add_subplot(5, 1, 3)
ax.plot(out_log[2, :]* 1000)
ax.set_title("S_c")
ax.set_xlim(0, 40)
ax.set_ylim(0.0, 0.06)

ax = fig.add_subplot(5, 1, 4)
ax.plot(out_log[3, :]* 1000)
ax.set_title("S_cc")
ax.set_xlim(0, 40)
ax.set_ylim(0.0, 0.04)

ax = fig.add_subplot(5, 1, 5)
ax.plot(out_log[4, :]* 1000)
ax.set_title("S_ccc")
ax.set_xlim(0, 40)
ax.set_ylim(0.0, 0.02)

plt.subplots_adjust(top=None, bottom=None, left=None, right=None, hspace=0.6, wspace=None)

plt.show()
