# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = np.load("./output/PHT3D_CASE_10/PHT3D_CASE_10_results.npy")
data.shape
# Out:
# (50, 7, 3200)

# %%
data = data.reshape(data.shape[0], 7, 40, 80)
data.shape
# Out:
# (50, 7, 40, 80)

# %%
plt.imshow(data[-1, 6], cmap="jet")
plt.colorbar()
